# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

# %%
# Colunas
nomes_colunas = ["Iteração", "Bubble", "Insertion", "Selection", "Busca Linear", "Busca Binária"]
# Lista dos tamanhos
tamanhos = ["100mil", "200mil", "400mil","800mil", "1600mil"] 
# Dataframe
resultados = {}

# %%
# Função para converter números formatados como string para inteiros
def converter_numero(valor):
  return int(str(valor).replace(".", "")) # remover pontos e transformar em inteiro

# %%
# Lista das médias
medias_custo_bubble = []
medias_custo_selection = []
medias_custo_insertion = []
medias_busca_linear = []
medias_busca_binaria = []

# %%
# Carregamento dos arquivos dos resultados
for tamanho in tamanhos:
    nome_arquivo = f"vetor{tamanho}.csv"
    df = pd.read_csv(f"vetor{tamanho}.csv", delimiter=';', skiprows=1, names=nomes_colunas, encoding="ISO-8859-1")

    # Converter strings em números
    for coluna in nomes_colunas[1:]: # pular coluna "Iteração"
        df[coluna] = df[coluna].apply(converter_numero)
    # Armazenar dataframe no dicionário
    resultados[tamanho] = df

    # Calcular médias
    medias_custo_bubble.append(df["Bubble"].mean())
    medias_custo_selection.append(df["Selection"].mean())
    medias_custo_insertion.append(df["Insertion"].mean())
    medias_busca_linear.append(df["Busca Linear"].mean())
    medias_busca_binaria.append(df["Busca Binária"].mean())

    # Exibir os dados
    print(f"Resultado do teste de {tamanho} vetores:")
    display(resultados[tamanho])
    print(f"Média Bubble: {df['Bubble'].mean()}")
    print(f"Média Selection: {df['Selection'].mean()}")
    print(f"Média Insertion: {df['Insertion'].mean()}")
    print(f"Média Busca Linear: {df['Busca Linear'].mean()}")
    print(f"Média Busca Binária: {df['Busca Binária'].mean()}")
    print("-"*100)
# Out:
# Resultado do teste de 100mil vetores:
#     Iteração       Bubble   Insertion   Selection  Busca Linear  Busca Binária
# 0          1   7503241615  5006583230  5000049986          7982     5006583246
# 1          2   7501244576  5002589152  5000049991         15477     5002589162
# 2          3  12517352946  5011701963  5001244601         14931     5001170198
# 3          4  12516382827  5011055217  5001252112         61865     5011055234
# 4          5  12508835583  5006023721  5001261886         14827     5006023738
# 5          6  12493796571  4995997713  5001255272         22247     4995997728
# 6          7  12512252919  5008301945  5001256671          3262     5008301962
# 7          8  12507630474  5005220315  5001257937         76175     5005220330
# 8          9  12502801599  5002001065  5001252968          4224     5002001079
# 9         10  12483641142  4989227427  5001247019         99594     4989227444
# 10        11  12502215843  5001610561  5001249743         55745     5001610577
# 11        12  12456385533  4971057021  5001255411          9385     4971057037
# 12        13  12499127433  4999551621  5001250706         96119     4999551637
# 13        14  12500302428  5000334951  5001257405         79189     5000334967
# 14        15  12479377038  4986384691  5001246375         50065     4986384708
# 15        16  12491546112  4994497407  5001253313          8498     4994497416
# 16        17  12488101410  4992200939  5001249966         82003     4992200955
# 17        18  12500810796  5000673863  5001249263         23426     5000673877
# 18        19  12495848043  4997365361  5001244378         37094     4997365377
# 19        20  12477228189  4984952125  5001259581          6714     4984952139
# 20        21  12492598347  4995198897  5001256883         17501     4995198912
# 21        22  12517958301  5012105533  5001253058            55     5012105550
# 22        23  12473416533  4982411021  5001247224         63146     4982411038
# 23        24  12486600948  4991200631  5001257428         19872     4991200646
# 20        21  799998896212  320000330807  320011690334        502285
# 21        22  799905947785  319938365189  320011710042        428914
# 22        23  800386557241  320258771493  320011708393        290248
# 23        24  799397159104  319599172735  320011721172        625239
# 24        25  800156305390  320105270259  320011671634        106158
# 25        26  799961168263  319975178841  320011734272        191769
# 26        27  800026553431  320018768953  320011663729        411733
# 27        28  799786999768  319859066511  320011721979        330909
# 28        29  799876336612  319918624407  320011702804        170894
# 29        30  799821736018  319882224011  320011715811        377986
#
#     Busca Binária
# 0    319839098479
# 1    319811866258
# 2    320111442647
# 3    319751764437
# 4    320298377733
# 5    319958266994
# 6    320189744793
# 7    320171528069
# 8    319774389305
# 9    320161542141
# 10   320275906663
# 11   319819915087
# 12   320383666969
# 13   320258896336
# 14   320249456473
# 15   319952385934
# 16   320270531703
# 17   320013511487
# 18   319894605217
# 19   320418099707
# 20   320000330826
# 21   319938365207
# 22   320258771513
# 23   319599172754
# 24   320105270277
# 25   319975178861
# 26   320018768971
# 27   319859066531
# 28   319918624426
# 29   319882224030
# Média Bubble: 800056438464.2
# Média Selection: 320011717966.3
# Média Insertion: 320038692308.4667
# Média Busca Linear: 360565.56666666665
# Média Busca Binária: 320038692327.6
# ----------------------------------------------------------------------------------------------------
# Resultado do teste de 1600mil vetores:
#    Iteração         Bubble      Insertion      Selection  Busca Linear  \
# 0         1  3200415798039  1279926386875  1280024569399       1436344
# 1         2  3199543553640  1279441289945  1280024551339        829100
# 2         3  3201171096288  1279904028343  1280024518384        701021
# 3         4  3200951530830  1279976304103  1280024505732        959108
# 4         5  3199411327782  1279922365811  1280024526980        146070
# 5         6  3200613666312  1280411244207  1280024547756         56133
# 6         7  3200474511588  1280318474391  1280024541128        989196
# 7         8  3199524021309  1279684814205  1280024492484       1006167
# 8         9  3198779318070  1279188345379  1280024569191        127028
# 9        10  3200048145501  1280034230333  1280024523493        125935
#
#    Busca Binária
# 0  1280064050844
# 1  1280431455428
# 2  1280143177298
# 3  1278617182778
# 4  1279300577517
# 5  1280411244227
# 6  1280318474409
# 7  1279684814225
# 8  1279188345399
# 9  1280034230353
# Média Bubble: 3200093296935.9
# Média Selection: 1280024534588.6
# Média Insertion: 1279880748359.2
# Média Busca Linear: 637610.2
# Média Busca Binária: 1279819355247.8
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Gráfico

# %%
plt.figure(figsize=(5, 10)) # tamanho do gráfico

# Bubble Sort
plt.plot(tamanhos, medias_custo_bubble, label="Bubble", color="r")
# Selection Sort
plt.plot(tamanhos, medias_custo_selection, label="Selection", color="g", linestyle="dashed", linewidth=5)
# Insertion Sort
plt.plot(tamanhos, medias_custo_insertion, label="Insertion", color="b")

# Formatar eixo Y para mostrar em bilhões
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x*1e-9:.0f}'))
# Definir limite do eixo Y -> cria um intervalo que melhora a visualização
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(nbins=30))

plt.title("Algoritmos de Ordenação: Custo por tamanho do vetor")
plt.xlabel("Tamanho do vetor")
plt.ylabel("Média do Custo (em bilhões)")
plt.legend() # exibir legenda
plt.grid(True) # exibir grid

plt.show()
